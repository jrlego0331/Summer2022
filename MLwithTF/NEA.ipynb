# %%
import tensorflow as tf
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

NEADataset = pd.read_csv('./archive/neo_v2.csv', index_col='id')
NEADataset.head(10)
# Out:
#                          name  est_diameter_min  est_diameter_max  \
# id
# 2162635   162635 (2000 SS164)          1.198271          2.679415
# 2277475     277475 (2005 WK4)          0.265800          0.594347
# 2512244    512244 (2015 YE18)          0.722030          1.614507
# 3596030           (2012 BV13)          0.096506          0.215794
# 3667127           (2014 GE35)          0.255009          0.570217
# 54138696          (2021 GY23)          0.036354          0.081291
# 54189957          (2021 PY40)          0.171615          0.383743
# 54230078           (2021 XD6)          0.005328          0.011914
# 2088213      88213 (2001 AF2)          0.350393          0.783502
# 3766065             (2016 YM)          0.105817          0.236614
#
#           relative_velocity  miss_distance orbiting_body  sentry_object  \
# id
# 2162635        13569.249224   5.483974e+07         Earth          False
# 2277475        73588.726663   6.143813e+07         Earth          False
# ...

# %%
plt.figure(figsize=(20, 6))
sns.scatterplot(data=NEADataset, x='name', size='est_diameter_max', hue='relative_velocity', y='miss_distance')
# Out:
# <AxesSubplot:xlabel='name', ylabel='miss_distance'>
